# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_excel('DataFinal.xlsx')
df
# Out:
#       No Kode Saham                 Industri                  Sector
# 0      1    DMMX.JK     Advertising Agencies  Communication Services
# 1      2    FORU.JK     Advertising Agencies  Communication Services
# 2      3    GMFI.JK      Aerospace & Defense             Industrials
# 3      4    KPAL.JK      Aerospace & Defense             Industrials
# 4      5    BISI.JK      Agricultural Inputs         Basic Materials
# ..   ...        ...                      ...                     ...
# 643  644    PGAS.JK  Utilities—Regulated Gas               Utilities
# 644  645    RAJA.JK  Utilities—Regulated Gas               Utilities
# 645  646    TGRA.JK      Utilities—Renewable               Utilities
# 646  647    INOV.JK         Waste Management             Industrials
# 647  648    OPMS.JK         Waste Management             Industrials
#
# [648 rows x 4 columns]

# %%
ids = input('Masukkan Industri : ')
perindustri = []
for i in range(len(df)):
    if df['Industri'][i] == ids:
        perindustri.append(df['Kode Saham'][i])
perindustri
# Out:
# Masukkan Industri : Trucking
# ['INPS.JK', 'JAYA.JK', 'SDMU.JK', 'TRUK.JK']

# %%
kds = input('Masukkan Kode Saham : ')
kode = []
xpl = []
for i in range(len(perindustri)):
    if perindustri[i] == kds:
        xpl.append(0.5)
    else:
        xpl.append(0)
data = []
for i in perindustri:
    info = yf.Ticker(i).info
    dta = info.get('marketCap')
    print(i, dta)
    kode.append(i)
    data.append(dta)
# Out:
# Masukkan Kode Saham : INPS.JK
# INPS.JK 994500018176
# JAYA.JK 52120600576
# SDMU.JK 56760999936
# TRUK.JK 70905004032

# %%
marcap = np.array(data)
marcaplb = kode
plt.rcParams['font.size'] = 16
exp = xpl
plt.title('Market Capitalization in '+ids+' Industry')
plt.pie(marcap, labels = marcaplb, autopct='%1.1f%%', explode = exp)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
boss = yf.Ticker('BOSS.JK')
boss.info
# Out:
# {'zip': '11410',
#  'sector': 'Energy',
#  'fullTimeEmployees': 35,
#  'longBusinessSummary': "PT. Borneo Olah Sarana Sukses Tbk operates as a coal exploration and production company in Indonesia. The company's mining assets are located in Muara Pahu, Kutai Barat, and East Kalimantan regions. It exports its products to Japan, South Korea, the United States, the Philippines, Thailand, Vietnam, Taiwan, India, and Bangladesh. The company was formerly known as PT. Megah Pratama Resources and changed its name to PT. Borneo Olah Sarana Sukses Tbk. PT. Borneo Olah Sarana Sukses Tbk was founded in 2011 and is based in Jakarta Barat, Indonesia.",
#  'city': 'Jakarta Barat',
#  'phone': '62 21 535 9777',
#  'country': 'Indonesia',
#  'companyOfficers': [],
#  'website': 'http://www.bosscoal.com',
#  'maxAge': 1,
#  'address1': 'Wisma 77 Building',
#  'fax': '62 21 536 1227',
#  'industry': 'Thermal Coal',
#  'address2': 'Tower 1 8th Floor Letjen S Parman No. 77',
#  'ebitdaMargins': 0,
#  'profitMargins': 0,
#  'grossMargins': -2.06904,
#  'operatingCashflow': -22293047296,
#  'revenueGrowth': -0.919,
#  'operatingMargins': -3.9888198,
#  'ebitda': -110584094720,
#  'targetLowPrice': None,
#  'recommendationKey': 'none',
#  'grossProfits': -8655853114,
#  'freeCashflow': 2560428288,
#  'targetMedianPrice': None,
#  'currentPrice': 88,
#  'earningsGrowth': None,
#  'currentRatio': 0.422,
#  'returnOnAssets': -0.11618,
#  'numberOfAnalystOpinions': None,
#  'targetMeanPrice': None,
#  'debtToEquity': 1014.024,
#  'returnOnEquity': -1.44298,
#  'targetHighPrice': None,
#  'totalCash': 1683316736,
#  'totalDebt': 290174205952,
#  'totalRevenue': 31307446272,
#  'totalCashPerShare': 1.202,
#  'financialCurrency': 'IDR',
#  'revenuePerShare': 22.364,
#  'quickRatio': 0.067,
#  'recommendationMean': None,
#  'exchange': 'JKT',
#  'shortName': 'Borneo Olah Sarana Sukses Tbk.',
#  'longName': 'PT. Borneo Olah Sarana Sukses Tbk',
#  'exchangeTimezoneName': 'Asia/Jakarta',
#  'exchangeTimezoneShortName': 'WIB',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '25200000',
#  'underlyingSymbol': None,
#  'quoteType': 'EQUITY',
#  'symbol': 'BOSS.JK',
#  'underlyingExchangeSymbol': None,
#  'headSymbol': None,
#  'messageBoardId': 'finmb_550965710',
#  'uuid': 'b1b52554-3868-39c4-ac83-aff4be0af7e4',
#  'market': 'id_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 13.463,
#  'beta3Year': None,
#  'enterpriseToEbitda': -3.812,
#  '52WeekChange': None,
#  'morningStarRiskRating': None,
#  'forwardEps': None,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 1400000000,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 101.278,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0,
#  'netIncomeToCommon': -147517358080,
#  'trailingEps': -37.4,
#  'lastDividendValue': None,
#  'SandP52WeekChange': None,
#  'priceToBook': 0.86889553,
#  'heldPercentInsiders': 0.44779998,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1625011200,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 872368000,
#  'beta': 0.450055,
#  'enterpriseValue': 421494325248,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': None,
#  'priceToSalesTrailing12Months': 3.935166,
#  'dateShortInterest': None,
#  'pegRatio': None,
#  'ytdReturn': None,
#  'forwardPE': None,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 89,
#  'regularMarketOpen': 90,
#  'twoHundredDayAverage': 83.95683,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 90,
#  'navPrice': None,
#  'averageDailyVolume10Day': 61583062,
#  'regularMarketPreviousClose': 89,
#  'fiftyDayAverage': 95.542854,
#  'trailingAnnualDividendRate': None,
#  'open': 90,
#  'averageVolume10days': 61583062,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 88,
#  'currency': 'IDR',
#  'regularMarketVolume': 2377200,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 123199995904,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 160511031,
#  'dayLow': 88,
#  'ask': 89,
#  'askSize': 0,
#  'volume': 2377200,
#  'fiftyTwoWeekHigh': 254,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 50,
#  'bid': 88,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 0,
#  'dayHigh': 90,
#  'regularMarketPrice': 88,
#  'logo_url': 'https://logo.clearbit.com/bosscoal.com'}
